# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import json

# %%
df_json=pd.read_json("file5.json")

# %%
df_json.head()
# Out:
#    results_found                                        restaurants  \
# 0            0.0                                                 []
# 1         6835.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
# 2            0.0                                                 []
# 3            0.0                                                 []
# 4         8680.0  [{'restaurant': {'has_online_delivery': 0, 'ph...
#
#    results_shown  results_start message  code status
# 0            0.0            1.0     NaN   NaN    NaN
# 1           20.0            1.0     NaN   NaN    NaN
# 2            0.0            1.0     NaN   NaN    NaN
# 3            0.0            1.0     NaN   NaN    NaN
# 4           20.0            1.0     NaN   NaN    NaN

# %%
pd.set_option("display.max_columns",26)
df=pd.read_csv("zomato.csv", encoding="unicode_escape")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df["Cuisines"].value_counts(normalize=True)
# Out:
# North Indian                                             0.098093
# North Indian, Chinese                                    0.053553
# Chinese                                                  0.037099
# Fast Food                                                0.037099
# North Indian, Mughlai                                    0.035003
#                                                            ...
# Bengali, Fast Food                                       0.000105
# North Indian, Rajasthani, Asian                          0.000105
# Chinese, Thai, Malaysian, Indonesian                     0.000105
# Bakery, Desserts, North Indian, Bengali, South Indian    0.000105
# Italian, World Cuisine                                   0.000105
# Name: Cuisines, Length: 1825, dtype: float64

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# # <h> check missing values

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[check_null for check_null in df if df[check_null].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
df.loc[df["Cuisines"].isnull()]
# Out:
#      Restaurant ID                 Restaurant Name  Country Code  \
# 84        17284105                   Cookie Shoppe           216
# 87        17284211  Pearly's Famous Country Cookng           216
# 94        17284158               Jimmie's Hot Dogs           216
# 297       17374552                  Corkscrew Cafe           216
# 328       17501439                        Dovetail           216
# 346       17606621            HI Lite Bar & Lounge           216
# 368       17059060                       Hillstone           216
# 418       17142698                Leonard's Bakery           216
# 455       17616465        Tybee Island Social Club           216
#
#                City                                          Address  \
# 84           Albany               115 N Jackson St, Albany, GA 31701
# 87           Albany             814 N Slappey Blvd, Albany, GA 31701
# 94           Albany               204 S Jackson St, Albany, GA 31701
# ...

# %%
sns.heatmap(df[["Cuisines"]].isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.isnull(),xticklabels=True,cbar=True,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
df_country=pd.read_excel("country-code.xlsx")

# %%
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df_full=pd.merge(df,df_country,on="Country Code",how="left")

# %%
df_full.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df_full.groupby("Country").sum()
# Out:
#                 Restaurant ID  Country Code      Longitude       Latitude  \
# Country
# Australia           401499310           336    3470.444000    -810.347137
# Brazil              412178472          1800   -2755.962201   -1246.807564
# Canada               66625338           148    -374.803601     188.803524
# India             74901100808          8652  630356.914840  228591.481428
# Indonesia           243557679          1974    2136.902576    -125.600651
# New Zealand         338784854          5920    6990.800727   -1526.252420
# Phillipines         186399716          3564    2662.794782     319.402638
# Qatar               220168523          3320    1030.257324     505.724090
# Singapore           369686941          3680    2076.974683      25.878322
# South Africa        464656967         11340    1494.305800   -1716.334183
# Sri Lanka           116013647          3820    1517.358992     131.182985
# ...

# %%
df_full["Country"].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
val=df_full["Country"].value_counts().values
val
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %%
index=df_full["Country"].value_counts().index
index
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object')

# %%
lab=df_full["Country"].value_counts(normalize=True)
lab
# Out:
# India             0.905874
# United States     0.045440
# United Kingdom    0.008376
# Brazil            0.006282
# UAE               0.006282
# South Africa      0.006282
# New Zealand       0.004188
# Turkey            0.003560
# Australia         0.002513
# Phillipines       0.002303
# Indonesia         0.002199
# Singapore         0.002094
# Qatar             0.002094
# Sri Lanka         0.002094
# Canada            0.000419
# Name: Country, dtype: float64

# %%
val=df_full["Country"].value_counts(normalize=True)
value=[x for x ,df_full in df_full.groupby(by="Country")]
value
# Out:
# ['Australia',
#  'Brazil',
#  'Canada',
#  'India',
#  'Indonesia',
#  'New Zealand',
#  'Phillipines',
#  'Qatar',
#  'Singapore',
#  'South Africa',
#  'Sri Lanka',
#  'Turkey',
#  'UAE',
#  'United Kingdom',
#  'United States']

# %%
fig=plt.figure(figsize=(5,5))
plt.pie(val[:3],labels=index[:3],autopct="%1.2F%%")
plt.show()

# %%
a=df_full.groupby(by=["Country","City"])["Country Code"].sum()
a.sort_values(ascending=False)
# Out:
# Country        City
# India          New Delhi       5473
# United States  Athens          4320
#                Albany          4320
#                Gainesville     4320
#                Dubuque         4320
#                                ...
# Australia      Balingup          14
#                Armidale          14
# India          Secunderabad       2
#                Mohali             1
#                Panchkula          1
# Name: Country Code, Length: 141, dtype: int64

# %%
a.index
# Out:
# Index(['Australia', 'Brazil', 'Canada', 'India', 'Indonesia', 'New Zealand',
#        'Phillipines', 'Qatar', 'Singapore', 'South Africa', 'Sri Lanka',
#        'Turkey', 'UAE', 'United Kingdom', 'United States'],
#       dtype='object', name='Country')

# %%
fig=plt.figure(figsize=(5,5))
sns.countplot(data=df_full,y=df_full["Country"],log=True)
plt.yticks(rotation="horizontal")
plt.show()

# %%
ind=df_full.loc[df_full["Country"]=="India"]
ind["Country"].value_counts()
# Out:
# India    8652
# Name: Country, dtype: int64

# %%
ratings=df_full.groupby(["Aggregate rating","Rating color","Rating text"]).size().reset_index().rename(columns=
                                                                                                       {0:"Rating_count"})
ratings.sort_values(by="Rating_count",ascending=False)
# Out:
#     Aggregate rating Rating color Rating text  Rating_count
# 0                0.0        White   Not rated          2148
# 15               3.2       Orange     Average           522
# 14               3.1       Orange     Average           519
# 17               3.4       Orange     Average           498
# 16               3.3       Orange     Average           483
# 18               3.5       Yellow        Good           480
# 13               3.0       Orange     Average           468
# 19               3.6       Yellow        Good           458
# 20               3.7       Yellow        Good           427
# 21               3.8       Yellow        Good           400
# 12               2.9       Orange     Average           381
# 22               3.9       Yellow        Good           335
# 11               2.8       Orange     Average           315
# 24               4.1        Green   Very Good           274
# 23               4.0        Green   Very Good           266
# ...

# %%
plt.figure(figsize=(12,6))
# import matplotlib
# matplotlib.rcParams["figure.figsize"]=(12,6)
sns.barplot(x="Aggregate rating",y="Rating_count",data=ratings)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating_count'>

# %%
sns.barplot(x="Aggregate rating",y="Rating_count",hue="Rating color",data=ratings,palette=["blue","red","orange","yellow",
                                                                                          "green","darkgreen"])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating_count'>

# %%
sns.countplot(x="Rating color",data=ratings,palette=["blue","red","orange","yellow","green","darkgreen"])
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %%
df_full["Rating color"].value_counts(normalize=True)
# Out:
# Orange        0.391268
# White         0.224898
# Yellow        0.219872
# Green         0.112972
# Dark Green    0.031515
# Red           0.019474
# Name: Rating color, dtype: float64

# %%
check=df_full.loc[df_full["Aggregate rating"]<=0]
check.head()
# Out:
#     Restaurant ID        Restaurant Name  Country Code            City  \
# 30        6600060         Sandubas Cafí©            30       Brasí_lia
# 58        7305048  Quiosque Chopp Brahma            30  Rio de Janeiro
# 69        6710645       Cantinho da Gula            30      Sí£o Paulo
# 77        6701419          Divino Fogí£o            30      Sí£o Paulo
# 78        6703956            Super Grill            30      Sí£o Paulo
#
#                                               Address  \
# 30  Edifí_cio Josí© Severo, SCS 6, Bloco A, Loja 9...
# 58  Madureira Shopping - Loja 289/290, Piso 2, Est...
# 69  Rua Pedroso Alvarenga, 522, Itaim Bibi, Sí£o P...
# 77  Shopping MetríÇ Santa Cruz - Piso L2, Rua Domi...
# 78  Shopping Morumbi - Piso Lazer, Avenida Roque P...
#
#                                     Locality  \
# 30                                   Asa Sul
# 58                                 Madureira
# 69                                Itaim Bibi
# ...

# %%
zero=check["Country"].value_counts()
zero=zero.reset_index().rename(columns={"index":"Country","Country":"Count"})
zero
# Out:
#           Country  Count
# 0           India   2139
# 1          Brazil      5
# 2   United States      3
# 3  United Kingdom      1

# %%
df_full[df_full["Aggregate rating"]==0].groupby("Country").size()
# Out:
# Country
# Brazil               5
# India             2139
# United Kingdom       1
# United States        3
# dtype: int64

# %%
sns.barplot(x="Country",y="Count",data=zero,log=True)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Count'>

# %%
df_full.groupby(["Country","Currency"]).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %%
df_full.groupby(["Country","Has Online delivery"]).size()
# Out:
# Country         Has Online delivery
# Australia       No                       24
# Brazil          No                       60
# Canada          No                        4
# India           No                     6229
#                 Yes                    2423
# Indonesia       No                       21
# New Zealand     No                       40
# Phillipines     No                       22
# Qatar           No                       20
# Singapore       No                       20
# South Africa    No                       60
# Sri Lanka       No                       20
# Turkey          No                       34
# UAE             No                       32
#                 Yes                      28
# United Kingdom  No                       80
# United States   No                      434
# dtype: int64

# %%
df_full.loc[df_full["Has Online delivery"]=="Yes","Country"].value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
plt.pie(x=df_full.City.value_counts().values[:5],labels=df_full.City.value_counts().index[:5],autopct="%1.2f%%")
plt.show()
